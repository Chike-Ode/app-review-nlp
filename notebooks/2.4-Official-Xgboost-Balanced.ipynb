# %%
import datasets as ds
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
import os
import numpy as np
import nltk
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
nltk.download('wordnet')
nltk.download('omw-1.4')
from yellowbrick.model_selection import FeatureImportances
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.utils import *
import joblib
# Out:
# /opt/conda/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/jovyan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
CUR_DIR = os.path.abspath(os.curdir)
ROOT_DIR = os.path.dirname(CUR_DIR)
IMAGES_DIR = os.path.join(ROOT_DIR, "images")
DATA_DIR = os.path.join(ROOT_DIR, "data")
MODELS_DIR = os.path.join(ROOT_DIR, "models")
MODELS_DIR
# Out:
# '/home/jovyan/projects/vector-nlp/models'

# %%
validation_df = pd.read_csv(os.path.join(DATA_DIR,'raw','validation.csv'))
training_df = pd.read_csv(os.path.join(DATA_DIR,'raw','training_balanced.csv'))
test_df = pd.read_csv(os.path.join(DATA_DIR,'raw','test.csv'))
training_df.star.value_counts()
# Out:
# 5    104524
# 4    104524
# 1    104524
# 2    104524
# 3    104524
# Name: star, dtype: int64

# %%
X_train = training_df['review']
y_train = training_df['star']

X_val = validation_df['review']
y_val = validation_df['star']

X_test = test_df['review']
y_test = test_df['star']


vect = TfidfVectorizer(max_df=0.8, min_df=2, stop_words='english')
X_train_tfidf = vect.fit_transform(X_train)
X_test_tfidf = vect.transform(X_test)
X_val_tfidf = vect.transform(X_val)

# %%
features = vect.vocabulary_.keys()
booster = XGBRegressor_v2(max_depth=15,n_estimators=150,name='2.4-XGBOOST-Tfidf-Balance')


eval_set = [(X_test_tfidf, y_test)]
# booster.fit(X_train,y_train,eval_metric="mae", eval_set=eval_set, verbose=True)
booster.fit(X_train_tfidf,y_train,eval_metric="mae", eval_set=eval_set, verbose=True)
# Out:
# [22:20:29] WARNING: ../src/learner.cc:576:
# Parameters: { "name" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-mae:2.74219
# [1]	validation_0-mae:2.28226
# [2]	validation_0-mae:1.96219
# [3]	validation_0-mae:1.76222
# [4]	validation_0-mae:1.61947
# [5]	validation_0-mae:1.51588
# [6]	validation_0-mae:1.44308
# [7]	validation_0-mae:1.38696
# [8]	validation_0-mae:1.34773
# [9]	validation_0-mae:1.31915
# [10]	validation_0-mae:1.29498
# [11]	validation_0-mae:1.27675
# [12]	validation_0-mae:1.26301
# [13]	validation_0-mae:1.25063
# [14]	validation_0-mae:1.23992
# [15]	validation_0-mae:1.23257
# [16]	validation_0-mae:1.22595
# [17]	validation_0-mae:1.22011
# [18]	validation_0-mae:1.21308
# [19]	validation_0-mae:1.20892
# [20]	validation_0-mae:1.20473
# [21]	validation_0-mae:1.19882
# [22]	validation_0-mae:1.19504
# [23]	validation_0-mae:1.19066
# [24]	validation_0-mae:1.18820
# [25]	validation_0-mae:1.18540
# [26]	validation_0-mae:1.18262
# [27]	validation_0-mae:1.18063
# [28]	validation_0-mae:1.17770
# [29]	validation_0-mae:1.17523
# [30]	validation_0-mae:1.17263
# [31]	validation_0-mae:1.17054
# [32]	validation_0-mae:1.16881
# [33]	validation_0-mae:1.16708
# [34]	validation_0-mae:1.16553
# [35]	validation_0-mae:1.16440
# [36]	validation_0-mae:1.16346
# [37]	validation_0-mae:1.16114
# [38]	validation_0-mae:1.16001
# [39]	validation_0-mae:1.15795
# [40]	validation_0-mae:1.15659
# [41]	validation_0-mae:1.15527
# [42]	validation_0-mae:1.15291
# [43]	validation_0-mae:1.15158
# [44]	validation_0-mae:1.14974
# [45]	validation_0-mae:1.14860
# [46]	validation_0-mae:1.14750
# [47]	validation_0-mae:1.14660
# [48]	validation_0-mae:1.14521
# [49]	validation_0-mae:1.14441
# [50]	validation_0-mae:1.14356
# [51]	validation_0-mae:1.14192
# [52]	validation_0-mae:1.14112
# [53]	validation_0-mae:1.14004
# [54]	validation_0-mae:1.13893
# [55]	validation_0-mae:1.13797
# [56]	validation_0-mae:1.13721
# [57]	validation_0-mae:1.13564
# [58]	validation_0-mae:1.13492
# [59]	validation_0-mae:1.13419
# [60]	validation_0-mae:1.13295
# [61]	validation_0-mae:1.13200
# [62]	validation_0-mae:1.13138
# [63]	validation_0-mae:1.13062
# [64]	validation_0-mae:1.12998
# [65]	validation_0-mae:1.12890
# [66]	validation_0-mae:1.12830
# [67]	validation_0-mae:1.12750
# [68]	validation_0-mae:1.12657
# [69]	validation_0-mae:1.12567
# [70]	validation_0-mae:1.12509
# [71]	validation_0-mae:1.12461
# [72]	validation_0-mae:1.12396
# [73]	validation_0-mae:1.12320
# [74]	validation_0-mae:1.12264
# [75]	validation_0-mae:1.12215
# [76]	validation_0-mae:1.12149
# [77]	validation_0-mae:1.12065
# [78]	validation_0-mae:1.11958
# [79]	validation_0-mae:1.11914
# [80]	validation_0-mae:1.11886
# [81]	validation_0-mae:1.11804
# [82]	validation_0-mae:1.11728
# [83]	validation_0-mae:1.11691
# [84]	validation_0-mae:1.11663
# [85]	validation_0-mae:1.11636
# [86]	validation_0-mae:1.11589
# [87]	validation_0-mae:1.11501
# [88]	validation_0-mae:1.11462
# [89]	validation_0-mae:1.11358
# [90]	validation_0-mae:1.11296
# [91]	validation_0-mae:1.11244
# [92]	validation_0-mae:1.11223
# [93]	validation_0-mae:1.11181
# [94]	validation_0-mae:1.11138
# [95]	validation_0-mae:1.11100
# [96]	validation_0-mae:1.11020
# [97]	validation_0-mae:1.10979
# [98]	validation_0-mae:1.10943
# [99]	validation_0-mae:1.10899
# [100]	validation_0-mae:1.10820
# [101]	validation_0-mae:1.10771
# [102]	validation_0-mae:1.10726
# [103]	validation_0-mae:1.10679
# [104]	validation_0-mae:1.10658
# [105]	validation_0-mae:1.10644
# [106]	validation_0-mae:1.10573
# [107]	validation_0-mae:1.10541
# [108]	validation_0-mae:1.10501
# [109]	validation_0-mae:1.10470
# [110]	validation_0-mae:1.10420
# [111]	validation_0-mae:1.10391
# [112]	validation_0-mae:1.10354
# [113]	validation_0-mae:1.10296
# [114]	validation_0-mae:1.10277
# [115]	validation_0-mae:1.10237
# [116]	validation_0-mae:1.10212
# [117]	validation_0-mae:1.10131
# [118]	validation_0-mae:1.10116
# [119]	validation_0-mae:1.10084
# [120]	validation_0-mae:1.10044
# [121]	validation_0-mae:1.10020
# [122]	validation_0-mae:1.09990
# [123]	validation_0-mae:1.09959
# [124]	validation_0-mae:1.09927
# [125]	validation_0-mae:1.09895
# [126]	validation_0-mae:1.09844
# [127]	validation_0-mae:1.09803
# [128]	validation_0-mae:1.09768
# [129]	validation_0-mae:1.09742
# [130]	validation_0-mae:1.09735
# [131]	validation_0-mae:1.09705
# [132]	validation_0-mae:1.09650
# [133]	validation_0-mae:1.09636
# [134]	validation_0-mae:1.09617
# [135]	validation_0-mae:1.09569
# [136]	validation_0-mae:1.09557
# [137]	validation_0-mae:1.09498
# [138]	validation_0-mae:1.09478
# [139]	validation_0-mae:1.09456
# [140]	validation_0-mae:1.09430
# [141]	validation_0-mae:1.09403
# [142]	validation_0-mae:1.09376
# [143]	validation_0-mae:1.09348
# [144]	validation_0-mae:1.09321
# [145]	validation_0-mae:1.09285
# [146]	validation_0-mae:1.09271
# [147]	validation_0-mae:1.09264
# [148]	validation_0-mae:1.09227
# [149]	validation_0-mae:1.09212
# XGBRegressor_v2(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 enable_categorical=False, gamma=0, gpu_id=-1,
#                 importance_type=None, interaction_constraints='',
#                 learning_rate=0.300000012, max_delta_step=0, max_depth=15,
#                 min_child_weight=1, missing=nan, monotone_constraints='()',
#                 n_estimators=150, n_jobs=8, name='2.4-XGBOOST-Tfidf-Balance',
#                 num_parallel_tree=1, objective='reg:squarederror',
#                 predictor='auto', random_state=0, reg_alpha=0, reg_lambda=1,
#                 scale_pos_weight=1, subsample=1, tree_method='exact',
#                 validate_parameters=1, verbosity=None)

# %%
performance_evaluation(X_test, y_test, booster, vect)
# Out:
# The prediction values range between 1.0 and 5.0
# Mean Absolute Error: 1.0678145557426275
# /home/jovyan/projects/vector-nlp/src/utils.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[bin_field_name] = pd.cut(eval_df[field], bins=bins, labels=labels)
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Performance appended successfully.
#               precision    recall  f1-score   support
#
#            1       0.85      0.17      0.28      7964
#            2       0.15      0.37      0.21      2640
#            3       0.12      0.52      0.20      4548
#            4       0.15      0.51      0.23      7414
#            5       0.89      0.13      0.23     35047
#
#     accuracy                           0.23     57613
#    macro avg       0.43      0.34      0.23     57613
# weighted avg       0.69      0.23      0.23     57613
#
# "I like the top but it took long to deliver" receives a score of [3.200022]
# "This app is trash" receives a score of [1.715336]
# "The app is extremely slow, but I still like it" receives a score of [2.9810026]
# "I Do not Love this App" receives a score of [4.417383]
# "Too many glitches" receives a score of [2.9257395]
# "Worthless app" receives a score of [1.7286016]
# "Do not download this app" receives a score of [2.524404]
# "Horrible" receives a score of [1.632223]
# "Could be better but is serviceable" receives a score of [3.3505263]
# "The servers are always down" receives a score of [2.9257395]
# None
# Done

# %%
#save model
joblib.dump(booster, os.path.join(MODELS_DIR,booster.name)) 
# model.save(os.path.join(MODELS_DIR,'2.1-LSTM_TFIDF'))
# Out:
# ['/home/jovyan/projects/vector-nlp/models/2.4-XGBOOST-Tfidf-Balance']
